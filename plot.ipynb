# %%
from volvar_fourier import *
import matplotlib.pyplot as pl

# %%
img = poisson_point_pattern(200,(3000,3000),30)

# %%
img1 = poisson_point_pattern(18,(3000,3000),100)

# %%
pl.imshow(img1)

# %%
vfr = volume_fraction_variance(img,0.33,10)

# %%
vfr1 = volume_fraction_variance(img1,0.33,10)

# %%
pl.plot(vfr[0],vfr[1]/0.02,'o')
pl.plot(vfr1[0],vfr1[1]/0.02,'o')
pl.loglog()
# Out:
# []

# %%
0.02*3000*3000/10000
# Out:
# 18.0
